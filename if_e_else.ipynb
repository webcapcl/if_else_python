# %%
idade = int(input('Digite sua idade '))
if idade >= 18:
  print('Voçê é maior de idade')
else:
  print('Voçê e menor de idade')

# %%
idade = int(input('Digite sua idade:'))
if idade <16:
  print('Voçê é menor de idade')
elif idade >= 15 and idade < 18:
  print('Voto opcional')
elif idade >= 18 and idade <= 75:
  print('Voto obrigatório')
else:
  print('Nehuma das opções')

# %%
pagamento = input('Digite a forma de pagamento')
if cartao
  print('Processando pagamento do cartão' )
